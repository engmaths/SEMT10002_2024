# %%
# %pip -q install ultralytics
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\aeagr\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov8n.pt")

# %%
# !wget https://seis.bristol.ac.uk/~aeagr/rovers.jpg
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
results = model('rovers.jpg')
# Out:
# image 1/1 c:\Users\aeagr\Local Documents\SEMT10002_2024\weekly_seminars\rovers.jpg: 352x640 1 truck, 86.3ms
# Speed: 3.5ms preprocess, 86.3ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)

# %%
len(results)
# Out:
# 1

# %%
for result in results:
    print(result.boxes)
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([7.])
# conf: tensor([0.2861])
# data: tensor([[8.3328e+01, 6.2274e+01, 1.4082e+03, 7.9295e+02, 2.8608e-01, 7.0000e+00]])
# id: None
# is_track: False
# orig_shape: (839, 1565)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 745.7850,  427.6106, 1324.9135,  730.6738]])
# xywhn: tensor([[0.4765, 0.5097, 0.8466, 0.8709]])
# xyxy: tensor([[  83.3282,   62.2737, 1408.2417,  792.9475]])
# xyxyn: tensor([[0.0532, 0.0742, 0.8998, 0.9451]])

# %%
class_id0 = results[0].boxes.cls.item()
print(results[0].names[class_id0])
# Out:
# truck

# %%
results[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=1565x839>
